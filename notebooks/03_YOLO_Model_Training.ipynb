# %%
import torch

print("PyTorch Version :", torch.__version__)
print("CUDA Available :", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU :", torch.cuda.get_device_name(0))
# Out:
# PyTorch Version : 2.11.0+cu128
# CUDA Available : True
# GPU : Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
from pathlib import Path

# Google Drive ZIP file
zip_path = "/content/drive/MyDrive/Smart_Warehouse_Inventory_Project.zip"

# Folder where the project will be extracted
extract_path = "/content"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("Project extracted successfully!")
# Out:
# Project extracted successfully!

# %%
import os
os.listdir("/content")
# Out:
# ['.config', 'drive', 'Smart_Warehouse_Inventory_ Project', 'sample_data']

# %%
import os

os.rename(
    "/content/Smart_Warehouse_Inventory_ Project",
    "/content/Smart_Warehouse_Inventory_Project"
)

# %%
import os
project_path = "/content/Smart_Warehouse_Inventory_Project"
print(os.listdir(project_path))
# Out:
# ['dataset', 'app', 'requirements.txt', 'predict.py', 'notebooks', 'output', 'utils', 'train.py']

# %%
from pathlib import Path
PROJECT_ROOT = Path("/content/Smart_Warehouse_Inventory_Project")
DATASET_PATH = PROJECT_ROOT / "dataset"
DATA_YAML = DATASET_PATH / "data.yaml"
print(DATA_YAML.exists())
print(DATASET_PATH.exists())
# Out:
# True
# True

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.4 MB/s eta 0:00:00

# %%
from pathlib import Path
import yaml
import ultralytics
from ultralytics import YOLO
print("Ultralytics Version :", ultralytics.__version__)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics Version : 8.4.104

# %%
PROJECT_ROOT = Path("/content/Smart_Warehouse_Inventory_Project")

DATASET_PATH = PROJECT_ROOT / "dataset"

DATA_YAML = DATASET_PATH / "data.yaml"

with open(DATA_YAML, "r") as file:
    data = yaml.safe_load(file)
print(f"Training Path : {data['train']}")
print(f"Validation Path : {data['val']}")
print(f"Test Path : {data['test']}")
print(f"Number of Classes : {data['nc']}")
# Out:
# Training Path : images/train
# Validation Path : images/val
# Test Path : images/test
# Number of Classes : 25

# %%
# Model Loading
model = YOLO("yolov8n.pt")
print("YOLO Model Loaded Successfully")
# Out:
# ...
# YOLO Model Loaded Successfully

# %%
# MOdel Trainig
results = model.train(
    data=str(DATA_YAML),
    epochs=20,
    imgsz=640,
    batch=16,
    device=0,
    workers=2,
    cache=False,
    name="warehouse_inventory"
)
# Out:
# Ultralytics 8.4.104 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
from pathlib import Path

source = Path("/content/runs/detect/warehouse_inventory")

destination = Path("/content/drive/MyDrive/YOLO_Training_imgsz640")

destination.mkdir(exist_ok=True)

shutil.copytree(
    source,
    destination / "warehouse_inventory",
    dirs_exist_ok=True
)

print("Training results copied successfully!")
# Out:
# Training results copied successfully!

# %%
import os

os.listdir("/content/drive/MyDrive/YOLO_Training_imgsz640/warehouse_inventory")
# Out:
# ['args.yaml',
#  'train_batch0.jpg',
#  'confusion_matrix_normalized.png',
#  'val_batch1_labels.jpg',
#  'val_batch0_labels.jpg',
#  'val_batch0_pred.jpg',
#  'train_batch2910.jpg',
#  'val_batch2_pred.jpg',
#  'train_batch2912.jpg',
#  'results.png',
#  'BoxR_curve.png',
#  'weights',
#  'labels.jpg',
#  'confusion_matrix.png',
#  'train_batch1.jpg',
#  'val_batch2_labels.jpg',
#  'results.csv',
#  'BoxF1_curve.png',
#  'BoxPR_curve.png',
#  'train_batch2911.jpg',
#  'val_batch1_pred.jpg',
#  'train_batch2.jpg',
#  'BoxP_curve.png']
